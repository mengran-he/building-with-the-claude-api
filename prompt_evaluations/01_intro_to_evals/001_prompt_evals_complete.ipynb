# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport json\nimport sys\n\ndef extract_s3_bucket_ids(template):\n    try:\n        if isinstance(template, str):\n            template = json.loads(template)\n        \n        s3_bucket_ids = []\n        \n        if 'Resources' in template:\n            for logical_id, resource in template['Resources'].items():\n                if resource.get('Type') == 'AWS::S3::Bucket':\n                    s3_bucket_ids.append(logical_id)\n        \n        return s3_bucket_ids\n    except json.JSONDecodeError:\n        return []\n\nif __name__ == \"__main__\":\n    template_input = sys.stdin.read()\n    result = extract_s3_bucket_ids(template_input)\n    print(json.dumps(result))\n",
#     "test_case": {
#       "task": "Parse an AWS CloudFormation template and extract all the logical IDs of resources that are of type 'AWS::S3::Bucket'",
#       "format": "python",
#       "solution_criteria": "Function should return a list of S3 bucket logical IDs from a CloudFormation template dict/JSON. Should handle templates where Resources section exists and filter by AWS::S3::Bucket type."
#     },
#     "score": 8.5,
#     "reasoning": "The solution successfully meets the stated criteria by extracting S3 bucket logical IDs from CloudFormation templates. The core logic is sound and handles the primary use case well. However, the error handling is too permissive (returning empty list on parse failure could indicate success when it indicates failure), and the solution is limited to JSON-only input when CloudFormation templates are often in YAML format. The lack of input validation could also lead to unexpected behavior if Resources isn't a dict."
#   },
#   {
#     "output": "\nimport json\nimport sys\n\ndef validate_iam_policy(policy_document):\n    \"\"\"Validate AWS IAM policy document structure.\"\"\"\n    try:\n        if isinstance(policy_document, str):\n            policy = json.loads(policy_document)\n        else:\n            policy = policy_document\n        \n        if not isinstance(policy, dict):\n            return False\n        \n        if \"Version\" not in policy:\n            return False\n        \n        if \"Statement\" not in policy:\n            return False\n        \n        if not isinstance(policy[\"Statement\"], list):\n            return False\n        \n        if len(policy[\"Statement\"]) == 0:\n            return False\n        \n        return True\n    except (json.JSONDecodeError, TypeError, ValueError):\n        return False\n\nif __name__ == \"__main__\":\n    test_cases = [\n        {\n            \"Version\": \"2012-10-17\",\n            \"Statement\": [\n                {\n                    \"Effect\": \"Allow\",\n                    \"Action\": \"s3:GetObject\",\n                    \"Resource\": \"arn:aws:s3:::bucket/*\"\n                }\n            ]\n        },\n        {\n            \"Version\": \"2012-10-17\",\n            \"Statement\": []\n        },\n        {\n            \"Statement\": [{\"Effect\": \"Allow\"}]\n        },\n        {\n            \"Version\": \"2012-10-17\"\n        },\n        \"invalid json\",\n        {\n            \"Version\": \"2012-10-17\",\n            \"Statement\": \"not a list\"\n        }\n    ]\n    \n    for i, test in enumerate(test_cases):\n        result = validate_iam_policy(test)\n        print(f\"Test {i+1}: {result}\")\n",
#     "test_case": {
#       "task": "Validate an AWS IAM policy document structure and ensure it contains required fields: Version, Statement, and that Statement is a non-empty list",
#       "format": "json",
#       "solution_criteria": "JSON object should represent a valid minimal IAM policy with Version (e.g., '2012-10-17'), at least one Statement with Effect and Action fields. Should demonstrate correct policy structure."
#     },
#     "score": 2.0,
#     "reasoning": "The solution validates the structural skeleton of an IAM policy but fails to meet the criteria requirement of ensuring each Statement contains Effect and Action fields. It correctly identifies invalid documents but would incorrectly accept malformed statements like {'Effect': 'Maybe'} or statements missing Action entirely. The validation is incomplete for what constitutes a 'valid minimal IAM policy' as specified in the criteria."
#   },
#   {
#     "output": "\n^[a-z0-9][a-z0-9\\-]{1,61}[a-z0-9]$|^[a-z0-9]$\n",
#     "test_case": {
#       "task": "Create a regex pattern that matches valid AWS S3 bucket names according to AWS naming rules (3-63 characters, lowercase letters, numbers, hyphens, and must start/end with letter or number)",
#       "format": "regex",
#       "solution_criteria": "Regex should match valid S3 bucket names (e.g., 'my-bucket-123', 'test-bucket'), reject invalid names (e.g., '-bucket', 'bucket-', 'Bucket', names under 3 chars or over 63 chars)."
#     },
#     "score": 8.5,
#     "reasoning": "The regex correctly implements the core requirements: lowercase/numbers only, alphanumeric start/end, and rejects hyphens at boundaries. However, the length constraint has a subtle flaw\u2014while it functionally works for most cases, the logic is convoluted. The pattern `[a-z0-9][a-z0-9\\-]{1,61}[a-z0-9]` correctly produces 3-63 character names (1+1-61+1), and the `|^[a-z0-9]$` alternative correctly handles single-character buckets. Testing confirms it rejects invalid inputs like '-bucket', 'bucket-', 'Bucket', and names outside the 3-63 range. The main issue is code clarity rather than functional correctness."
#   }
# ]
