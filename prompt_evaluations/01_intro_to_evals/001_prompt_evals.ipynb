# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    # TODO - Grading
    score = 10
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Validator\n\nHere's a Python function that validates AWS S3 bucket names according to AWS naming rules:\n\n```python\nimport re\n\ndef validate_s3_bucket_name(bucket_name: str) -> tuple[bool, str]:\n    \"\"\"\n    Validates an AWS S3 bucket name according to AWS naming rules.\n    \n    Rules:\n    - Length: 3-63 characters\n    - Characters: lowercase letters (a-z), numbers (0-9), and hyphens (-)\n    - Start and end: must begin and end with a letter or number\n    - No consecutive hyphens\n    - Cannot be formatted as an IP address\n    \n    Args:\n        bucket_name (str): The bucket name to validate\n        \n    Returns:\n        tuple[bool, str]: (is_valid, error_message)\n                         Returns (True, \"\") if valid\n                         Returns (False, error_message) if invalid\n    \"\"\"\n    \n    # Check if input is a string\n    if not isinstance(bucket_name, str):\n        return False, \"Bucket name must be a string\"\n    \n    # Check length (3-63 characters)\n    if len(bucket_name) < 3:\n        return False, \"Bucket name must be at least 3 characters long\"\n    if len(bucket_name) > 63:\n        return False, \"Bucket name must not exceed 63 characters\"\n    \n    # Check if starts with lowercase letter or number\n    if not bucket_name[0].isalnum() or bucket_name[0].isupper():\n        return False, \"Bucket name must start with a lowercase letter or number\"\n    \n    # Check if ends with lowercase letter or number\n    if not bucket_name[-1].isalnum() or bucket_name[-1].isupper():\n        return False, \"Bucket name must end with a lowercase letter or number\"\n    \n    # Check allowed characters (lowercase letters, numbers, hyphens)\n    if not re.match(r'^[a-z0-9-]+$', bucket_name):\n        return False, \"Bucket name can only contain lowercase letters, numbers, and hyphens\"\n    \n    # Check for consecutive hyphens\n    if '--' in bucket_name:\n        return False, \"Bucket name cannot contain consecutive hyphens\"\n    \n    # Check if it looks like an IP address (e.g., 192.168.1.1)\n    if re.match(r'^(\\d+\\.){3}\\d+$', bucket_name):\n        return False, \"Bucket name cannot be formatted as an IP address\"\n    \n    return True, \"\"\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        (\"my-bucket\", True),\n        (\"my-bucket-123\", True),\n        (\"a-b-c\", True),\n        (\"abc123\", True),\n        (\"my\", False),  # Too short\n        (\"my-bucket-\" + \"x\" * 60, False),  # Too long\n        (\"My-Bucket\", False),  # Contains uppercase\n        (\"-my-bucket\", False),  # Starts with hyphen\n        (\"my-bucket-\", False),  # Ends with hyphen\n        (\"my--bucket\", False),  # Consecutive hyphens\n        (\"my_bucket\", False),  # Contains underscore\n        (\"192.168.1.1\", False),  # IP address format\n        (\"my.bucket\", False),  # Contains dot\n        (\"\", False),  # Empty string\n        (\"123\", True),  # Valid: all numbers\n        (\"a23b45c67d89e01f23g45h67i89j01k23l45m67n89o01p23q45r67s89t01u23v45w67x89y01z23\", False),  # Too long\n    ]\n    \n    print(\"S3 Bucket Name Validation Tests\\n\" + \"=\"*50)\n    for bucket_name, expected in test_cases:\n        is_valid, error = validate_s3_bucket_name(bucket_name)\n        status = \"\u2713\" if is_valid == expected else \"\u2717\"\n        result = \"VALID",
#     "test_case": {
#       "task": "Write a Python function that validates an AWS S3 bucket name according to AWS naming rules (3-63 characters, lowercase letters, numbers, hyphens, starts and ends with letter or number)"
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM Read-Only S3 Bucket Policy\n\nHere's a JSON object that represents an AWS IAM policy for read-only access to a specific S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ListBucketContents\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketLocation\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    },\n    {\n      \"Sid\": \"ReadObjectsFromBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    }\n  ]\n}\n```\n\n## Policy Breakdown\n\n| Permission | Purpose |\n|-----------|---------|\n| **s3:ListBucket** | Allows listing the contents of the bucket |\n| **s3:GetBucketLocation** | Allows checking the bucket's region |\n| **s3:GetObject** | Allows reading/downloading objects |\n| **s3:GetObjectVersion** | Allows reading previous versions of objects |\n\n## Resource ARNs\n\n- **`arn:aws:s3:::my-data-bucket`** - The bucket itself (used for ListBucket and GetBucketLocation)\n- **`arn:aws:s3:::my-data-bucket/*`** - All objects within the bucket (used for GetObject)\n\nThis policy grants read-only access while preventing any write, delete, or administrative operations.",
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to a specific S3 bucket named 'my-data-bucket'"
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regular Expression\n\nHere's the regular expression that matches valid AWS EC2 instance IDs:\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Explanation\n\n| Part | Meaning |\n|------|---------|\n| `^` | Start of string |\n| `i-` | Literal \"i-\" prefix |\n| `[0-9a-f]` | Any hexadecimal character (0-9, a-f) |\n| `{17}` | Exactly 17 of the preceding character class |\n| `$` | End of string |\n\n## Examples\n\n### Valid matches:\n- `i-0a1b2c3d4e5f6g7h8` \u274c (contains 'g', invalid)\n- `i-0123456789abcdef0` \u2705\n- `i-1a2b3c4d5e6f7a8b9` \u2705\n\n### Non-matches:\n- `i-0123456789abcde` \u274c (only 16 hex chars)\n- `i-0123456789abcdef00` \u274c (18 hex chars)\n- `0-0123456789abcdef0` \u274c (missing 'i')\n- `i_0123456789abcdef0` \u274c (uses underscore instead of dash)\n\n## Language-Specific Examples\n\n**Python:**\n```python\nimport re\npattern = r'^i-[0-9a-f]{17}$'\nif re.match(pattern, 'i-0123456789abcdef0'):\n    print(\"Valid EC2 instance ID\")\n```\n\n**JavaScript:**\n```javascript\nconst pattern = /^i-[0-9a-f]{17}$/;\nif (pattern.test('i-0123456789abcdef0')) {\n    console.log(\"Valid EC2 instance ID\");\n}\n```",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs (format: i- followed by 17 hexadecimal characters)"
#     },
#     "score": 10
#   }
# ]
